# %%
# %load_ext autoreload
# %autoreload 2

#recharge tout seul le notebook (2prmiere lignes)
    
import numpy as np
import scipy as sp
#import pyccl as ccl
import math
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D
from scipy import integrate
from functools import partial
from scipy.integrate import quad, dblquad

import pyccl as ccl
import camb
from camb import model, initialpower
import cosmology
#import fisher_matrix_local_png
import fisher_matrix_bao_SuEisenstein
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
h=0.677
deltac=1.686
H0=100*h
c_ls=300*10**3
nlim=10000
n_s=0.968

cosmo = ccl.Cosmology(Omega_c=0.27, Omega_b=0.045, h=h, A_s=2.1e-9, n_s=n_s,transfer_function='boltzmann_camb')

# %%
zarray=np.linspace(1,6,350)
nz=np.exp(-((zarray-3)**2/(2*0.5**2)))
bz=3*np.ones((350))
Area=15000
N_degm2=2000

# %%
list_zbin, list_sigma_Da,list_sigma_H, zeff, sigma_Da_eff, sigma_H_eff=fisher_matrix_bao_SuEisenstein.sigma_Da_H_single_tracer(zarray,nz,bz,Area,N_degm2,Deltaz=0.4,cosmo=cosmo)

# %%
plt.figure(dpi=100)
plt.errorbar(list_zbin,list_sigma_Da,xerr=0.2,marker='o',linestyle='',color='crimson',label = 'Da per-redshift bin constraint')
plt.errorbar(list_zbin,list_sigma_H,xerr=0.2,marker='o',linestyle='',color='olive',label = 'H per-redshift bin constraint')



plt.ylabel(r'$\sigma(Da)$ or $\sigma(H)$ ',fontsize=12)
plt.xlabel(r'$z_{\rm bin}$',fontsize=12)
#plt.yscale('log')
plt.ylim(0,0.01)
plt.xlim(0, 6)
plt.plot(zarray, nz/100, label = 'n(z) not normalized')
plt.legend()

# %%
Fisher_mat_w0wa = fisher_matrix_bao_SuEisenstein.sigma_w0_wa_eff(zeff, sigma_Da_eff, sigma_H_eff, cosmo, w0=-1.0, wa=0.0, corr_DaH=0.0, rel_step=1e-2)

# %%
F
# Out:
# array([[26260.63346669,  6870.03118695],
#        [ 6870.03118695,  1856.98687065]])

# %%
np.linalg.inv(F).diagonal()**.5
# Out:
# array([0.03441016, 0.12940017])
